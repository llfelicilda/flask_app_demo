# %%
import pandas as pd
import numpy as np
import csv
from sqlalchemy import create_engine

# %%
user='root'
host='localhost'
port = 3306
database = '6Steps'
engine = create_engine(
        url="mysql+pymysql://{0}@{1}:{2}/{3}".format(
            user, host, port, database
        )
    )
conn = engine.connect()

# %% [markdown]
# # PDR

# %%
process_tech_df = pd.read_excel("../data/database table.xlsx", sheet_name="Process Tech table", usecols=["process_name","Process_tech_name"])
process_tech_df["process_name"].fillna(method="ffill", inplace=True)
process_tech_df.rename(columns={'Process_tech_name': 'process_tech_name'}, inplace=True)
process_tech_df.head()
# Out:
#   process_name process_tech_name
# 0   Die_Attach       Soft solder
# 1   Die_Attach      Solder paste
# 2   Die_Attach  Diffusion solder
# 3   Die_Attach             Epoxy
# 4   Die_Attach               DAF

# %%
PBC_df = pd.read_excel("../data/database table.xlsx", 
                       sheet_name="PBC table", 
                       usecols=["PBC_name"], 
                       na_filter=False
                      )
PBC_df["PBC_color"] = PBC_df.PBC_name.apply(lambda row: row.split("(", 1)[-1].rstrip(")'") if not pd.isnull(row) else row)
PBC_df.head()
# Out:
#               PBC_name PBC_color
# 0                   NA        NA
# 1     standard_(green)     green
# 2     limited_(yellow)    yellow
# 3     restricted_(red)       red
# 4  unclassified_(grey)      grey

# %%
process_table = process_tech_df.join(PBC_df, how="cross")

# %%
process_table.head(3)
# Out:
#   process_name process_tech_name          PBC_name PBC_color
# 0   Die_Attach       Soft solder                NA        NA
# 1   Die_Attach       Soft solder  standard_(green)     green
# 2   Die_Attach       Soft solder  limited_(yellow)    yellow

# %%
process_table[(process_table['process_name']=="Die_Attach") & (process_table['process_tech_name']=="Diffusion solder") & (process_table['PBC_name']=="standard_(green)")]
# Out:
#    process_name process_tech_name          PBC_name PBC_color
# 11   Die_Attach  Diffusion solder  standard_(green)     green

# %%
def table_to_sql (table, table_name, primary_key=None, float_cols=[], m=4, d=2, int_cols=[]):
    cols_size = []
    str_cols = [c for c in table.columns if c not in [primary_key]+float_cols+int_cols]
    for col in str_cols:
        max_len = int(max(table[col].astype(str).str.len()) * 1.5)
        cols_size.append((col, max_len))

    df_sql = """
    CREATE TABLE {table_name} 
    (
    {pk_col}{cols}{float_cols}{int_cols}{pk}
    );
    """.format(table_name=table_name,
               pk_col='{} INT NOT NULL AUTO_INCREMENT, '.format(primary_key) if primary_key else '',
               pk=', PRIMARY KEY ({})'.format(primary_key) if primary_key else '',
               cols=", ".join(["`{c}` varchar({s}) DEFAULT NULL".format(c=c, s=s) for c, s in cols_size]),
               float_cols=", "+", ".join(["`{c}` float({m},{d}) DEFAULT NULL".format(c=c,m=m,d=d) for c in float_cols]) if float_cols else "",
               int_cols=", "+", ".join(["`{c}` INT DEFAULT NULL".format(c=c) for c in int_cols]) if int_cols else ""
              )
    return(df_sql)

# %%
# conn.execute("drop table Process_PBHB_mapping;")
# conn.execute("drop table PDR_sessions;")

# %%
process_table.head(3)
# Out:
#   process_name process_tech_name          PBC_name PBC_color
# 0   Die_Attach       Soft solder                NA        NA
# 1   Die_Attach       Soft solder  standard_(green)     green
# 2   Die_Attach       Soft solder  limited_(yellow)    yellow

# %%
conn.execute("DROP TABLE Process_PBHB_mapping;")
conn.execute("DROP TABLE Process;")

conn.execute(table_to_sql(process_table, 'Process', 'process_id'))

process_table.to_sql('Process', conn, if_exists='append', index=False)

# %%
PBHB_wirebond = pd.read_excel("../data/Z8F67581994_PBHB wire bond.xlsx", 
                              sheet_name="PB IN_Process", 
                              header=1,
                              usecols=range(7,7+11),
                              skiprows=[2,3]
                            )
PBHB_wirebond.columns = ['PB_code'] + [' '.join(c.split()).lower() for c in PBHB_wirebond.columns[1:]]

PBHB_wirebond
# Out:
#    PB_code                                       requirements  \
# 0    INP01   Ball/bump bond dimension within bond pad opening
# 1    INP02  Wedge bond width within bond pad opening and l...
# 2    INP03           Stitch bond dimension within lead finger
# 3    INP04  Verticle ball/bump bond dimension from bond pa...
# 4    INP05               Symmetrical/regular ball bond shape
# 5    INP06  Ball bond neck condition without crack, thinni...
# 6    INP07  Ball/bump bond adhesion strength in terms of s...
# 7    INP08  Wedge bond adhesion strength in terms of shear...
# 8    INP09  Ball bond adhesion strength in terms of pull f...
# 9    INP10  Stitch bond adhesion strength in terms of pull...
# 10   INP11  Wedge bond adhesion strength in terms of pull ...
# 11   INP12  Ball/bump bond position within bond pad openin...
# 12   INP13            Stitch bond position within lead finger
# 13   INP14  Wedge bond position within bond pad opening an...
# 14   INP15  Good bond adhesion without causing bond pad da...
# 15   INP16  Intermetallic compound (IMC) coverage area at ...
# 16   INP18  Stitch bond heel condition without stress mark...
# 17   INP19  Wedge bond heel condition without stress mark ...
# 18   INP20  Ball bond: Bond interface condition between st...
# 19   INP21  Verticle dimension of wire looping profile as ...
# 20   INP22  Wire loop profile with sufficient clearance be...
# 21   INP23  Thickness of Aluminum bond pad metallization a...
# 22   INP24  Profile measurement of pad liner after removal...
# 23   INP25    Aluminium metal layer\ncondition below bond pad
# 24   INP26  Functionality of protection layer against bond...
# 25   DAP14  Contamination of active surfaces (bond pad and...
# 26  PDP005                C distribution enables good bonding
# 27  PDP006               Low F content within the first 10 nm
# 28  PDP007                           Low F content at surface
# 29  PDP008  Low content of unintended material (metals, or...
# 30  PDP009          Si precipitates do no lead to bad bonding
# 31  PDP010  Native oxide thickness thin enough to ensure g...
# 32  PDP011     Homogenity of  protection layer over the wafer
# 33  PDP012                Pitch distance enables good bonding
# 34  PDP013  Surface physical condition: hillock, pitting (...
# 35  PDP014  Si precipitates do no lead to ILD cracks\nfor ...
# 36  PDP015  Funtionality of protection layer against oxida...
# 37  PDP016                      Low reactivity of pad surface
# 38  PDP017  No damage of underlying layers after interconn...
# 39  PDP018                     Roughness enables good bonding
# 40  PDP019     Design related topography enables good bonding
# 41  PDP020  After test the pad should have a uniform metal...
# 42  PDP021  No damage of underlying layers after interconn...
#
#             parameter (input to pdr: output response) in adego rev. 7.0  \
# 0   Ball/bump bond diameter\ni) Along X-axis\nii) ...                No
# 1   Wedge bond width\ni) At bond pad\nii) At lead ...                No
# 2   Stitch bond dimension\ni) Stitch width\nii) St...                No
# 3                    Ball/bump bond height \n(Z-axis)               Yes
# 4                                     Ball bond shape               Yes
# 5                            Ball bond neck condition               Yes
# 6                Ball/bump bond shear force/strength                Yes
# 7   Wedge shear force\ni) At bond pad\nii) At lead...               Yes
# 8                                     Ball pull force               Yes
# 9                                   Stitch pull force               Yes
# 10                                    Wire pull force               Yes
# 11                           Ball/bump bond placement               Yes
# 12                             Stitch bond placement                Yes
# 13                              Wedge bond placement                Yes
# 14                                 Bond pad cratering               Yes
# 15  IMC coverage \nApplicable for:\n(i) Au wire on...               Yes
# 16                         Stitch bond heel condition                No
# 17                          Wedge bond heel condition                No
# 18               Stitch/wedge bond interface gap/void                No
# 19                                        Loop height                No
# 20                            Loop profile clearance                Yes
# 21  Aluminum bond pad metallization remnant thickn...                No
# 22             Deformation of layers below bond pad                  No
# 23                                  Pad Bending Ratio                No
# 24                 Pro.Cu bond pad visual inspection                 No
# 25  1. Appearance of foreign elements\n2. O thickn...                No
# 26                 C distribution (amount, thickness)                No
# 27                 F distribution (amount, thickness)                No
# 28                            F surface concentration                No
# 29             Material concentration on pad surface                 No
# 30  Si precipitation grain size at surface and Si ...                No
# 31         Thickness of native pad oxide (AlOx, CuOx)                No
# 32                      Thickness of protection layer                No
# 33                                     Measure pitch                 No
# 34                Physical defect on bond pad surface                No
# 35                Si precipitation grain size in bulk                No
# 36  Visible changes of pad surface (discolouration...                No
# 37  Visible changes of pad surface (discolouration...                No
# 38                           Hardness of pad surface                 No
# 39                              Pad surface roughness                No
# 40  Evaluate design induced Max-Min of FS Metal St...               NaN
# 41          Probemark depth and size measurent on Pad                No
# 42                      Damage energy and crack force                No
#
#                    verification method (input to pdr)  \
# 0                            Light Optical Inspection
# 1                            Light Optical Inspection
# 2                            Light Optical Inspection
# 3                            Light Optical Inspection
# 4                            Light Optical Inspection
# 5                    SEM\n(Magnification: 1000x min.)
# 6                                     Ball Shear Test
# 7                                    Wedge Shear Test
# 8                                     Ball Pull Test
# 9                                   Stitch Pull Test
# 10                                    Wire Pull Test
# 11                           Light Optical Inspection
# 12                           Light Optical Inspection
# 13                           Light Optical Inspection
# 14    Wet Chemical Etching + Light Optical Inspection
# 15  Wet Chemical Etching + Light Optical Inspectio...
# 16                   SEM\n(Magnification: 1000x min.)
# 17                   SEM\n(Magnification: 1000x min.)
# 18  Cross Section + SEM\n(Magnification: 1000x min...
# 19                           Light Optical Inspection
# 20                           Light Optical Inspection
# 21         Cross Section + \nLight Optical Inspection
# 22                               Optical Profilometer
# 23                                Cross Section + SEM
# 24                                     Hot plate test
# 25                                                AES
# 26                                                AES
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  TEM\n\n\n**The thicknesses measured in TEM are...
# 33                           Light Optical Inspection
# 34                                                NaN
# 35  Selective chemical etching of Al, measure the ...
# 36                                     Hot plate test
# 37                                       Wet box test
# 38                                       Nanoindenter
# 39                Optical light interferometer  (WLI)
# 40                                                NaN
# 41                                                NaN
# 42  Microindenter tester and AE sensor (in develop...
#
#             development target (spec#) (input to pdr)  \
# 0   As per related specification requirement.\n\nT...
# 1   As per related specification requirement.\n(on...
# 2   As per related specification requirement or MI...
# 3   As per related process specification requireme...
# 4   Reject golf club formation if the center point...
# 5   No wire crack above wire neck (heat affected z...
# 6   As per related process specification or indust...
# 7   As per related process specification and Gener...
# 8   As per related process specification and Gener...
# 9   As per related process specification and Gener...
# 10  As per related process specification and Gener...
# 11  Shall be 100% within bond pad opening/lead fin...
# 12  Reject if stitch bond is not 100% within lead ...
# 13  Shall be 100% within bond pad opening and lead...
# 14  No cratering or micro-crack at interlayer\ndie...
# 15  IMC coverage percentage :\n(i) Au wire on AlCu...
# 16  No heel stress mark and crack @ HH or VHVH par...
# 17  No heel stress mark and crack @ HH or paramete...
# 18  No gaps or void at the bond interfaces at LL o...
# 19  As per Project Requirement Profile and process...
# 20  As per Assembly Design Rule Check and Failure ...
# 21  Aluminum metallization thickness (thinnest poi...
# 22  Assess minimum layer thickness deformation OR ...
# 23  No aluminium squeeze out from layer below bond...
# 24  No changes in visual appearance of bond pad be...
# 25  1. no appearance of foreign elements\n2. O < 1...
# 26      C layer thickness < 1nm (in AES depthprofile)
# 27  F peak max not at surface, no exponential decr...
# 28  Alu pad with Au ball bond/ Cu ball bond:Spec o...
# 29                 No signals of unintended elements
# 30                                 Spec of Si < 1 at%
# 31  Alu pad with wedge bond/ Auball/ Cu ball bond:...
# 32  Homogen thickness according to typical values ...
# 33              Symmetries according to design layout
# 34  No discoloration, foreign material, scratches,...
# 35  No Si grains at wire position  ==> to be updat...
# 36  No changes in optical appearance of chips befo...
# 37  No corrosion in optical appearance of chips be...
# 38  The development target is to have a database f...
# 39  The development target reference values are av...
# 40  Symmetries according to design layout \nspec f...
# 41  To be updated in the next PBHB Revision  after...
# 42  pad strength > 0.7N for 50um diameter diamond ...
#
#                            sample size (input to pdr)  \
# 0   30 wires x number of lots @ each required proc...
# 1   30 wires x number of lots @ each required proc...
# 2   30 wires x number of lots @ each required proc...
# 3   30 wires x number of lots @ each required proc...
# 4   30 wires x number of lots (shall include 4  di...
# 5   Minimum 5 balls per unit from minimum 2 units ...
# 6   30 wires from minimum 5 units x number of lots...
# 7   30 wires x number of lots @ each required proc...
# 8   30 wires from minimum 5 units x number of lots...
# 9   30 wires from minimum 5 units x number of lots...
# 10  30 wires x number of lots @ each required proc...
# 11  100% VI on  bonded units or max 1 leadframe wh...
# 12  100% VI on  bonded units or max 1 leadframe wh...
# 13  100% VI on 30 bonded units or max 1 leadframe ...
# 14  5 units all pads x number of lots @ HH or VHVH...
# 15  Minimum 30 bonds from minimum 2 units x number...
# 16  Minimun 2 stitches x number of lots @ HH or VH...
# 17  Minimum 2 wedges x number of lots @ HH process...
# 18  \nMinimum 1 bond x number of lots @ LL or VLVL...
# 19  30 wires x number of lots @ each required loop...
# 20  100% VI on 30 bonded units (all wires) or maxi...
# 21  Minimum 1 pad x number of lots @ each required...
# 22  Minimum 1 pad x number of lots @ HH or VHVH pr...
# 23  Minimum 1 pad x number of lots @ HH or VHVH pr...
# 24  Minimum 1 bond pad x number of lots @ each req...
# 25                 2 dies from LL and 2 dies from HH
# 26              1 Wafer: \n1 chip center\n1 chip edge
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32              1 Wafer: \n1 chip center\n1 chip edge
# 33              1 Wafer: \n1 chip center\n1 chip edge
# 34                                                NaN
# 35              1 Wafer: \n1 chip center\n1 chip edge
# 36              1 Wafer: \n1 chip center\n1 chip edge
# 37              1 Wafer: \n1 chip center\n1 chip edge
# 38  1 Wafer: \n1 chip center  \n1 chip edge\n\nREM...
# 39              1 Wafer: \n1 chip center\n1 chip edge
# 40                                                NaN
# 41                                                NaN
# 42  1 wafer  sawn in sample with 16(±1)mm × 16(±1)...
#
#                        take sample after process step  \
# 0                                  After Interconnect
# 1                                  After Interconnect
# 2                                  After Interconnect
# 3                                  After Interconnect
# 4                                  After Interconnect
# 5                                  After Interconnect
# 6                                  After Interconnect
# 7                                  After Interconnect
# 8                                  After Interconnect
# 9                                  After Interconnect
# 10                                 After Interconnect
# 11                                 After Interconnect
# 12                                 After Interconnect
# 13                                 After Interconnect
# 14                                 After Interconnect
# 15                                 After Interconnect
# 16                                 After Interconnect
# 17                                 After Interconnect
# 18                                 After Interconnect
# 19                                 After Interconnect
# 20                                 After Interconnect
# 21                                 After Interconnect
# 22                                 After Interconnect
# 23                                 After Interconnect
# 24         After Plasma Clean \n(Before Interconnect)
# 25                                   After Die-Attach
# 26  If Pad continues after passivation the samples...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  If Pad continues after passivation the samples...
# 33  If Pad continues after passivation the samples...
# 34                                                NaN
# 35  If Pad continues after passivation the samples...
# 36  Just in case of protection layer; If Pad conti...
# 37  Just in case of protection layer; If Pad conti...
# 38  Just in case of protection layer; If Pad conti...
# 39  After test (if Pad processes are performed aft...
# 40                                                NaN
# 41                                                NaN
# 42  If Pad continues after passivation the samples...
#
#           lab instruction (input in pdr)       (primary) interaction to pb  \
# 0                       Work Instruction                      Interconnect
# 1                       Work Instruction                      Interconnect
# 2                       Work Instruction                      Interconnect
# 3                       Work Instruction                      Interconnect
# 4                       Work Instruction                      Interconnect
# 5                        Lab Instruction                      Interconnect
# 6                       Work Instruction  Interconnect / Adhesion Promoter
# 7                       Work Instruction  Interconnect / Adhesion Promoter
# 8                       Work Instruction  Interconnect / Adhesion Promoter
# 9                       Work Instruction  Interconnect / Adhesion Promoter
# 10                      Work Instruction  Interconnect / Adhesion Promoter
# 11                      Work Instruction                      Interconnect
# 12                      Work Instruction                      Interconnect
# 13                      Work Instruction                      Interconnect
# 14                       Lab Instruction                      Interconnect
# 15                       Lab Instruction                      Interconnect
# 16                       Lab Instruction                      Interconnect
# 17                       Lab Instruction                      Interconnect
# 18                       Lab Instruction  Interconnect/ Adhesion Promoter
# 19                      Work Instruction                     Encapsulation
# 20                      Work Instruction                     Encapsulation
# 21    Lab Instruction update in progress                      Interconnect
# 22                       Lab Instruction                      Interconnect
# 23                       Lab Instruction                      Interconnect
# 24                       Lab Instruction                      Interconnect
# 25                       Lab Instruction                       Die- Attach
# 26                       Lab Instruction                               NaN
# 27                                   NaN                               PAD
# 28                                   NaN                               NaN
# 29                                   NaN                               NaN
# 30                                   NaN                               NaN
# 31                                   NaN                               NaN
# 32                       Lab Instruction                               PAD
# 33                     Lab Instruction\n                               PAD
# 34                                   NaN                               NaN
# 35     Lab Instruction\nupdate ongoing\n                               PAD
# 36                     Lab Instruction\n                               PAD
# 37  Lab Instruction under construction\n                               PAD
# 38                    Lab Instruction \n                               PAD
# 39                     Lab Instruction\n                               PAD
# 40                                   NaN                               PAD
# 41                                   NaN                               PAD
# 42                     Lab Instruction\n                               PAD
#
#                                            motivation
# 0   To avoid ball/bump bond out of bond pad, short...
# 1   To avoid wedge bond out of bond pad/lead finge...
# 2   To avoid broken stitch/wedge, lifted stitch/we...
# 3   To avoid lifted ball/bump bond, smashed ball/b...
# 4   To avoid lifted ball bond, smashed ball,  dama...
# 5   To avoid neck stress, wire thinning, necking, ...
# 6       Good ball/bump bond adhesion with bond pad.\n
# 7             Good wedge bond adhesion with bond pad.
# 8   Good ball bond adhesion with bond pad\nTo avoi...
# 9   Good stitch bond adhesion with lead finger\n\n...
# 10  Good wedge bond adhesion with bond pad and lea...
# 11  To avoid electrical test failure due to offset...
# 12  To avoid electrical test failure due to offset...
# 13  To avoid electrical test failure due to offset...
# 14  To avoid  bond pad damage, electrical open, el...
# 15       Good bond adhesion to avoid ball/bump bond\n
# 16       To avoid stitch bond heel stress and crack\n
# 17       To avoid wedge bond heel  stress and crack\n
# 18  To prevent broken stitch/wedge, lifted stitch/...
# 19                             To avoid exposed wire
# 20  To ensure sufficient stand off and clearance t...
# 21  To prevent bond pad damage and  reliability co...
# 22  To prevent bond pad damage and  reliability co...
# 23  To prevent electrical short caused by aluminiu...
# 24  To avoid weak ball bond adhesion that might le...
# 25  Outgases from the DA material (glue or solder ...
# 26     Bad bond adhesion (low ball/wedge shear, NSOP)
# 27                      Corrosion (bad bond adhesion)
# 28     Bad bond adhesion (low ball/wedge shear, NSOP)
# 29  Bad bond adhesion (low ball/wedge shear, NSOP)...
# 30     Bad bond adhesion (low ball/wedge shear, NSOP)
# 31  Bad bond adhesion (low ball/wedge shear, NSOP)...
# 32     Bad bond adhesion (low ball/wedge shear, NSOP)
# 33     Bad bond adhesion (low ball/wedge shear, NSOP)
# 34     Bad bond adhesion (low ball/wedge shear, NSOP)
# 35                                           el. Fail
# 36     Bad bond adhesion (low ball/wedge shear, NSOP)
# 37                      Corrosion (bad bond adhesion)
# 38                            el. Fail, lifted wire..
# 39     Bad bond adhesion (low ball/wedge shear, NSOP)
# 40           Bad bond adhesion (low ball shear, NSOP)
# 41  At wb bad bond adhesion (too little metal rema...
# 42  To avoid bond pad stack damage in wire bonding...

# %%
PBHB_die_attach = pd.read_excel("../data/Z8F65720674_Die Attach.xlsx", 
                              sheet_name="PB DA_Process", 
                              header=1,
                              usecols=range(10,10+11),
                              skiprows=[2,3]
                            )
PBHB_die_attach.columns = list(PBHB_wirebond.columns)
PBHB_die_attach["PB_code"] = PBHB_die_attach["PB_code"].apply(lambda row: row.replace("\n", ""))
PBHB_die_attach
# Out:
#          PB_code                                       requirements  \
# 0   DAP01 /PUP01     Visual defects after die Pick-Up (die surface)
# 1          DAP02                            Visual defects after DA
# 2          DAP03      Translational and rotational offsets of die\n
# 3         DAP04a                                           Coverage
# 4         DAP04b  Coverage (solder wetting), solder bridging and...
# 5         DAP04b  Coverage (solder wetting), solder bridging and...
# 6         DAP04c                                           Coverage
# 7         DAP05a                                       Void content
# 8         DAP05b  Void content and delamination (DAP05b is used ...
# 9         DAP05c             Solder joint crack / solder joint void
# 10        DAP05c             Solder joint crack / solder joint void
# 11         DAP06             Bond-Line thickness (BLT) and die tilt
# 12         DAP07                                      Fillet height
# 13         DAP08  Die-Bond strength (only required for DS for di...
# 14        DAP05b  Void content and delamination (both delaminati...
# 15         DAP08  Die-Bond strength (solder wire, solder paste &...
# 16         DAP09                                 Clip-Bond strength
# 17         DAP10  Formation of IMC and barrier integrity at BSM ...
# 18        DAP11   Formation of IMC and barrier integrity at FSM ...
# 19         DAP12  Continuity of IMC and clip-tilt (for new clip ...
# 20         DAP13  IMC composition (only checked when new process...
# 21         DAP14  Contamination of active surfaces (bond pad and...
# 22         DAP15                                 Lead-frame warpage
# 23        PDP005                C distribution enables good bonding
# 24        PDP010  Native oxide thickness thin enough to ensure g...
# 25         BSP08                      Chip bow below critical limit
# 26         SEP27  Die Strength requirements \n(according to deli...
# 27         SEP31                                      Sticking dies
#
#             parameter (input to pdr: output response) in adego rev. 7.0  \
# 0   Traces of any visual damages, contamination an...               Yes
# 1   Traces of any visual damages, contamination an...               Yes
# 2      1. x Offset\n2. y Offset\n3. Rotational offset               Yes
# 3                                           Coverage                Yes
# 4   1. Coverage \n2. Solder bridging\n3. Solder ex...                No
# 5   1. Mal-formation of solder lump / uneven squee...                No
# 6                                           Coverage                 No
# 7                   Void content (area of voids in %)               Yes
# 8                   Void content (area of voids in %)               Yes
# 9                                Appearance of crack                 No
# 10                         Appearance of solder voids                No
# 11                                1. BLT\n2. Die tilt               Yes
# 12                                      Fillet height               Yes
# 13          1. Die-shear strength\n2. Die-shear force                No
# 14  1. Percent area of delamination\n2. Void conte...               Yes
# 15          1. Die-Shear strength\n2. Die-Shear force                No
# 16            1. Failure modes\n2. Clip-Pull strength                No
# 17  1. Thickness of remaining solder active materi...                No
# 18                   Remained active solder thickness                No
# 19  1. Continuity of IMC at both the clip-side and...                No
# 20        1. Require presence of Sn at solder remnant                No
# 21  1. Appearance of foreign elements\n2. O thickn...                No
# 22                          1. Cross bow\n2. Coil set                No
# 23                 C distribution (amount, thickness)                No
# 24         Thickness of native pad oxide (AlOx, CuOx)                No
# 25                                           Chip Bow                No
# 26                                     Breakage force                No
# 27                                     Number of Dies                No
#
#                    verification method (input to pdr)  \
# 0                            Light Optical Inspection
# 1                            Light Optical Inspection
# 2                            Light Optical Inspection
# 3                            Light Optical Inspection
# 4                            Light Optical Inspection
# 5                                               X-ray
# 6                                               X-RAY
# 7               X-RAY \n(not for non-conductive glue)
# 8   SAM \n(preferred for leadfree solder wire and ...
# 9   Cross-Section (on lateral / vertical plane), F...
# 10                                      CT-scan/X-ray
# 11                           Light Optical Inspection
# 12                           Light Optical Inspection
# 13                                     Die Shear Test
# 14                                                SAM
# 15                                     Die Shear Test
# 16                                     Clip Pull Test
# 17              Embedded Cross Section, FIB, SEM, EDX
# 18              Embedded Cross Section, FIB, SEM, EDX
# 19                       Embedded Cross Section,  SEM
# 20                  Embedded Cross Section,  SEM, EDX
# 21                                                AES
# 22                           Light Optical Inspection
# 23                                                AES
# 24                                                AES
# 25                               Chip Bow Measurement
# 26  Tool: Instron \n3-point bending method for det...
# 27  Peeling force, pull test method in discussion ...
#
#             development target (spec#) (input to pdr)  \
# 0   a. No cracked die\nb. No die-corner chipping\n...
# 1   a. No improper die placement, improper die pic...
# 2   Min. Criteria:\n1. x offset <100 μm\n2. y offs...
# 3   Solder wire, solder paste, glue:\ncoverage > 7...
# 4   1. no insufficient solder coverage\n2. no sold...
# 5   No mal-formation of solder lump / uneven squee...
# 6                   as per respective failure catalog
# 7   min. Criteria:\nPackage criteria : Exposed pad...
# 8   min. Criteria:\nPackage criteria : Exposed pad...
# 9                                            No crack
# 10                          ≤30% of solder joint area
# 11  per released process specification for details...
# 12  \n\n1. Chip thickness >= 125um  : Fillet heigh...
# 13  per released process specification\n\nIf proce...
# 14  min. Criteria:\nPackage criteria : Exposed pad...
# 15  per released process specification\n\nreferenc...
# 16  per released process specification\n\nreferenc...
# 17  1. min. Remained active solder layer in BSM:\n...
# 18  min. remained active solder in FSM:\n     a. 1...
# 19  1. appearance of continuous IMC \n2. clip-tilt...
# 20  1. Sn exists in between the Cu6Sn5/Cu3Sn IMC l...
# 21  1. no appearance of foreign elements\n2. O < 1...
# 22  per process specification\n\nreference guideli...
# 23                            C layer thickness < 1nm
# 24  Alu pad with wedge bond/ Auball/ Cu ball bond:...
# 25  Warstein: <25µm: uncritical\nbetween 25 and 40...
# 26  1) Industrie-Standard 3-point bend test and ba...
# 27                         Specifications from PA R&D
#
#                            sample size (input to pdr)  \
# 0                           30 dies \nADeGo:\n45 dies
# 1   10 dies per LF x 3 LFs\nADeGo:\n15 dies per LF...
# 2   10 dies per LF x 3 LFs \nADeGo:\n15 dies per L...
# 3   10 dies per LF x 3 LFs \nADeGo:\n15 dies per L...
# 4                                   30 dies on one LF
# 5                5 units per map from 1 strip per lot
# 6                           10 dies per LF x 3 LFs \n
# 7                           10 dies per LF x 3 LFs \n
# 8                           10 dies per LF x 3 LFs \n
# 9                                            3 Units
# 10               5 units per map from 1 strip per lot
# 11  10 dies per LF x 3 LFs \nADeGo:\n15 dies per L...
# 12  10 dies per LF x 3 LFs \nADeGo:\n15 dies per L...
# 13  General DA tech.:\n10 dies per LF x 3 LFs\n\nC...
# 14                          10 dies per LF x 3 LFs \n
# 15                             10 dies per LF x 3 LFs
# 16                             10 dies per LF x 3 LFs
# 17                  2 dies from LL and 2 dies from HH
# 18  2 dies from LL and 2 dies from HH (measured at...
# 19  2 dies from LL and 2 dies from HH (measured at...
# 20             5 units per array from 1 strip per lot
# 21                 2 dies from LL and 2 dies from HH
# 22                                       3 leadframes
# 23              1 Wafer: \n1 chip center\n1 chip edge
# 24              1 Wafer: \n1 chip center\n1 chip edge
# 25  2 Wafers out of 2 lots:\n1 chip center, \n1 ch...
# 26  1 Wafer per Lot:\n100 dies w/ Frontside stress...
# 27                                        from PA R&D
#
#                        take sample after process step  \
# 0                                   After die Pick-Up
# 1                                    After Die-Attach
# 2                                    After Die-Attach
# 3                                    After Die-Attach
# 4                                    After Die-Attach
# 5                                       After Molding
# 6                                    After Die-Attach
# 7                                   After Die-Attach
# 8                                    After Die-Attach
# 9                                       After Molding
# 10                                  After Singulation
# 11       After Die-Attach \n(after curing for glue)\n
# 12                                   After Die-Attach
# 13                                   After Die-Attach
# 14                                   After Die-Attach
# 15                                   After Die-Attach
# 16                                   After Die-Attach
# 17  After relevant stress tests , or in case of re...
# 18              After Die Attach or machine stoppage
# 19                                  After Die-Attach
# 20                                  After Singulation
# 21                                   After Die-Attach
# 22                                 After Die Attach\n
# 23  If Pad continues after passivation the samples...
# 24  If Pad continues after passivation the samples...
# 25                                   After Separation
# 26                                   After Separation
# 27                                   After Separation
#
#         lab instruction (input in pdr) (primary) interaction to pb  \
# 0                     Work Instruction                Interconnect
# 1                     Work Instruction                Interconnect
# 2                     Work Instruction                Interconnect
# 3                     Work Instruction                Interconnect
# 4                     Work Instruction                         Nil
# 5                     Work Instruction                         Nil
# 6                     Work Instruction                Interconnect
# 7                     Work Instruction                Interconnect
# 8                     Work Instruction                Interconnect
# 9                    Lab Instruction\n                         Nil
# 10  Lab Instruction under construction                Interconnect
# 11                    Work Instruction                Interconnect
# 12                    Work Instruction                Interconnect
# 13                    Work Instruction                Interconnect
# 14                   Lab Instruction\n                Interconnect
# 15                   Lab Instruction\n                Interconnect
# 16                   Lab Instruction\n                Interconnect
# 17                   Lab Instruction\n              Backside Metal
# 18                   Lab Instruction\n                         Pad
# 19                   Lab Instruction\n                         Pad
# 20                   Lab Instruction\n                         Nil
# 21                     Lab Instruction                Interconnect
# 22                    Work Instruction                Interconnect
# 23                     Lab Instruction                Interconnect
# 24                     Lab Instruction                Interconnect
# 25                     Lab Instruction                  Die-Attach
# 26                    Work Instruction                    Thinning
# 27                   Lab Instruction\n                  Die-Attach
#
#                                            motivation
# 0   Physical damages of a die could lead to variou...
# 1   any contamination, improper die/clip placement...
# 2   Inaccurate die placement could lead to:\ni. In...
# 3   Insufficient coverage could lead to:\ni. Weak ...
# 4   Insufficient coverage could lead to:\ni. Weak ...
# 5   Insufficient coverage could lead to:\ni. Weak ...
# 6   Insufficient coverage could lead to:\ni. Weak ...
# 7   Voids could lead to:\ni. Weakened die-bond for...
# 8   Voids could lead to:\ni. Weakened die-bond for...
# 9   Voids and solder joint cracks could lead to:\n...
# 10  Voids could lead to:\ni. Weakened die shear st...
# 11  1. BLT affects all functional performances of ...
# 12  Overflow of glue may lead to:\ni. Contaminatio...
# 13  i. Fundamentally a die-bond has to fulfill cer...
# 14  Delamination could lead to:\ni. Weakened die-b...
# 15  i. Fundamentally a die-bond has to fulfill cer...
# 16  i. A clip-bond has to fulfill certain mechanic...
# 17  Improper formation of IMC could lead to:\ni. W...
# 18  Improper formation of IMC could lead to:\ni. w...
# 19  Appearance of a continuous IMC is an evidence ...
# 20  Solder remnant insufficiency could harm long t...
# 21  Outgases from the DA material (glue or solder ...
# 22  Significant leadframe warpage could hinder the...
# 23           Bad bond adhesion (low ball shear, NSOP)
# 24  Bad bond adhesion (low ball shear, NSOP), void...
# 25  High chip bow can cause voids in the die attac...
# 26  No die cracks at customer/assembly or in field...
# 27                            Die-Attach not possible

# %%
PBHB_df = pd.concat([PBHB_wirebond, PBHB_die_attach], ignore_index=True)
PBHB_df
# Out:
#    PB_code                                       requirements  \
# 0    INP01   Ball/bump bond dimension within bond pad opening
# 1    INP02  Wedge bond width within bond pad opening and l...
# 2    INP03           Stitch bond dimension within lead finger
# 3    INP04  Verticle ball/bump bond dimension from bond pa...
# 4    INP05               Symmetrical/regular ball bond shape
# ..     ...                                                ...
# 66  PDP005                C distribution enables good bonding
# 67  PDP010  Native oxide thickness thin enough to ensure g...
# 68   BSP08                      Chip bow below critical limit
# 69   SEP27  Die Strength requirements \n(according to deli...
# 70   SEP31                                      Sticking dies
#
#             parameter (input to pdr: output response) in adego rev. 7.0  \
# 0   Ball/bump bond diameter\ni) Along X-axis\nii) ...                No
# 1   Wedge bond width\ni) At bond pad\nii) At lead ...                No
# 2   Stitch bond dimension\ni) Stitch width\nii) St...                No
# 3                    Ball/bump bond height \n(Z-axis)               Yes
# 4                                     Ball bond shape               Yes
# ..                                                ...               ...
# 66                 C distribution (amount, thickness)                No
# 67         Thickness of native pad oxide (AlOx, CuOx)                No
# 68                                           Chip Bow                No
# 69                                     Breakage force                No
# 70                                     Number of Dies                No
#
#                    verification method (input to pdr)  \
# 0                            Light Optical Inspection
# 1                            Light Optical Inspection
# 2                            Light Optical Inspection
# 3                            Light Optical Inspection
# 4                            Light Optical Inspection
# ..                                                ...
# 66                                                AES
# 67                                                AES
# 68                               Chip Bow Measurement
# 69  Tool: Instron \n3-point bending method for det...
# 70  Peeling force, pull test method in discussion ...
#
#             development target (spec#) (input to pdr)  \
# 0   As per related specification requirement.\n\nT...
# 1   As per related specification requirement.\n(on...
# 2   As per related specification requirement or MI...
# 3   As per related process specification requireme...
# 4   Reject golf club formation if the center point...
# ..                                                ...
# 66                            C layer thickness < 1nm
# 67  Alu pad with wedge bond/ Auball/ Cu ball bond:...
# 68  Warstein: <25µm: uncritical\nbetween 25 and 40...
# 69  1) Industrie-Standard 3-point bend test and ba...
# 70                         Specifications from PA R&D
#
#                            sample size (input to pdr)  \
# 0   30 wires x number of lots @ each required proc...
# 1   30 wires x number of lots @ each required proc...
# 2   30 wires x number of lots @ each required proc...
# 3   30 wires x number of lots @ each required proc...
# 4   30 wires x number of lots (shall include 4  di...
# ..                                                ...
# 66              1 Wafer: \n1 chip center\n1 chip edge
# 67              1 Wafer: \n1 chip center\n1 chip edge
# 68  2 Wafers out of 2 lots:\n1 chip center, \n1 ch...
# 69  1 Wafer per Lot:\n100 dies w/ Frontside stress...
# 70                                        from PA R&D
#
#                        take sample after process step  \
# 0                                  After Interconnect
# 1                                  After Interconnect
# 2                                  After Interconnect
# 3                                  After Interconnect
# 4                                  After Interconnect
# ..                                                ...
# 66  If Pad continues after passivation the samples...
# 67  If Pad continues after passivation the samples...
# 68                                   After Separation
# 69                                   After Separation
# 70                                   After Separation
#
#    lab instruction (input in pdr) (primary) interaction to pb  \
# 0                Work Instruction                Interconnect
# 1                Work Instruction                Interconnect
# 2                Work Instruction                Interconnect
# 3                Work Instruction                Interconnect
# 4                Work Instruction                Interconnect
# ..                            ...                         ...
# 66                Lab Instruction                Interconnect
# 67                Lab Instruction                Interconnect
# 68                Lab Instruction                  Die-Attach
# 69               Work Instruction                    Thinning
# 70              Lab Instruction\n                  Die-Attach
#
#                                            motivation
# 0   To avoid ball/bump bond out of bond pad, short...
# 1   To avoid wedge bond out of bond pad/lead finge...
# 2   To avoid broken stitch/wedge, lifted stitch/we...
# 3   To avoid lifted ball/bump bond, smashed ball/b...
# 4   To avoid lifted ball bond, smashed ball,  dama...
# ..                                                ...
# 66           Bad bond adhesion (low ball shear, NSOP)
# 67  Bad bond adhesion (low ball shear, NSOP), void...
# 68  High chip bow can cause voids in the die attac...
# 69  No die cracks at customer/assembly or in field...
# 70                            Die-Attach not possible
#
# [71 rows x 11 columns]

# %%
conn.execute("DROP TABLE PB_Handbook;")
conn.execute(table_to_sql(PBHB_df, 'PB_Handbook'))
PBHB_df.to_sql('PB_Handbook', conn, if_exists='replace', index=False)

# %%
PBHB_wirebond = pd.read_excel("../data/Z8F67581994_PBHB wire bond.xlsx", 
                              sheet_name="PB IN_Process", 
                              header=2,
                              usecols=range(1,8),
                              skiprows=[3]
                            )
PBHB_wirebond.rename(columns={'#': 'PB_code'}, inplace=True)
PBHB_wirebond['process_name'] = 'Interconnect'
PBHB_wirebond
# Out:
#    Au ball Cu ball Al wedge Au wedge Green & yellow Red & grey PB_code  \
# 0        X       X      NaN      NaN              X        NaN   INP01
# 1      NaN     NaN        X        X              X        NaN   INP02
# 2        X       X      NaN      NaN              X        NaN   INP03
# 3        X       X      NaN      NaN              X        NaN   INP04
# 4        X       X      NaN      NaN              X        NaN   INP05
# 5        X       X      NaN      NaN              X        NaN   INP06
# 6        X       X      NaN      NaN              X        NaN   INP07
# 7      NaN     NaN        X        X              X        NaN   INP08
# 8        X       X      NaN      NaN              X        NaN   INP09
# 9        X       X      NaN      NaN              X        NaN   INP10
# 10     NaN     NaN        X        X              X        NaN   INP11
# 11       X       X      NaN      NaN              X        NaN   INP12
# 12       X       X      NaN      NaN              X        NaN   INP13
# 13     NaN     NaN        X        X              X        NaN   INP14
# 14       X       X        X        X              X        NaN   INP15
# 15       X       X      NaN      NaN              X        NaN   INP16
# 16       X       X      NaN      NaN              X        NaN   INP18
# 17     NaN     NaN        X        X              X        NaN   INP19
# 18       X       X        X        X              X        NaN   INP20
# 19       X       X        X        X              X        NaN   INP21
# 20       X       X        X        X              X        NaN   INP22
# 21       X       X        X      NaN              X        NaN   INP23
# 22     NaN       X      NaN      NaN            NaN          X   INP24
# 23     NaN       X      NaN      NaN            NaN          X   INP25
# 24     NaN       X      NaN      NaN            NaN          X   INP26
# 25       X       X        X        X            NaN          X   DAP14
# 26       X       X        X        X            NaN          X  PDP005
# 27       X       X        X        X            NaN          X  PDP006
# 28       X       X        X        X            NaN          X  PDP007
# 29       X       X        X        X            NaN          X  PDP008
# 30       X       X        X        X            NaN          X  PDP009
# 31       X       X        X        X            NaN          X  PDP010
# 32       X       X        X        X            NaN          X  PDP011
# 33       X       X        X        X            NaN          X  PDP012
# 34       X       X        X        X            NaN          X  PDP013
# 35       X       X        X        X            NaN          X  PDP014
# 36       X       X        X        X            NaN          X  PDP015
# 37       X       X        X        X            NaN          X  PDP016
# 38     NaN       X      NaN      NaN            NaN          X  PDP017
# 39       X       X        X        X            NaN          X  PDP018
# 40     NaN       X      NaN      NaN            NaN          X  PDP019
# 41       X       X        X        X            NaN          X  PDP020
# 42     NaN       X      NaN      NaN            NaN          X  PDP021
#
#     process_name
# 0   Interconnect
# 1   Interconnect
# 2   Interconnect
# 3   Interconnect
# 4   Interconnect
# 5   Interconnect
# 6   Interconnect
# 7   Interconnect
# 8   Interconnect
# 9   Interconnect
# 10  Interconnect
# 11  Interconnect
# 12  Interconnect
# 13  Interconnect
# 14  Interconnect
# 15  Interconnect
# 16  Interconnect
# 17  Interconnect
# 18  Interconnect
# 19  Interconnect
# 20  Interconnect
# 21  Interconnect
# 22  Interconnect
# 23  Interconnect
# 24  Interconnect
# 25  Interconnect
# 26  Interconnect
# 27  Interconnect
# 28  Interconnect
# 29  Interconnect
# 30  Interconnect
# 31  Interconnect
# 32  Interconnect
# 33  Interconnect
# 34  Interconnect
# 35  Interconnect
# 36  Interconnect
# 37  Interconnect
# 38  Interconnect
# 39  Interconnect
# 40  Interconnect
# 41  Interconnect
# 42  Interconnect

# %%
PBHB_die_attach = pd.read_excel("../data/Z8F65720674_Die Attach.xlsx", 
                              sheet_name="PB DA_Process", 
                              header=2,
                              usecols=range(1,11),
                              skiprows=[3]
                            )
PBHB_die_attach.rename(columns={'Unnamed: 10': "PB_code"}, inplace=True)
PBHB_die_attach["PB_code"] = PBHB_die_attach["PB_code"].apply(lambda row: row.replace("\n", ""))
PBHB_die_attach['process_name'] = 'Die_Attach'
PBHB_die_attach
# Out:
#    Soft solder Solder paste Diffusion solder Epoxy  DAF Cu Pillar FC  \
# 0            X            X                X     X    X            X
# 1            X            X                X     X    X            X
# 2            X            X                X     X    X            X
# 3            X            X                X     X    X          NaN
# 4          NaN          NaN              NaN   NaN  NaN            X
# 5          NaN          NaN              NaN   NaN  NaN            X
# 6          NaN          NaN              NaN   NaN  NaN          NaN
# 7            X            X                X     X  NaN          NaN
# 8            X            X                X     X    X          NaN
# 9          NaN          NaN              NaN   NaN  NaN            X
# 10         NaN          NaN              NaN   NaN  NaN            X
# 11           X            X              NaN     X  NaN          NaN
# 12         NaN          NaN              NaN     X  NaN          NaN
# 13         NaN          NaN                X     X    X            X
# 14           X            X                X     X    X          NaN
# 15           X            X                X   NaN  NaN          NaN
# 16         NaN          NaN              NaN   NaN  NaN          NaN
# 17           X            X                X   NaN  NaN          NaN
# 18         NaN          NaN              NaN   NaN  NaN          NaN
# 19         NaN          NaN              NaN   NaN  NaN          NaN
# 20         NaN          NaN              NaN   NaN  NaN            X
# 21         NaN            X              NaN     X  NaN          NaN
# 22           X            X                X   NaN  NaN            X
# 23         NaN            X              NaN     X  NaN          NaN
# 24         NaN            X              NaN     X  NaN          NaN
# 25           X            X                X     X    X            X
# 26           X            X                X     X    X            X
# 27           X            X                X     X    X            X
#
#    Clip Bond Green & yellow Red & grey       PB_code process_name
# 0        NaN              X        NaN  DAP01 /PUP01   Die_Attach
# 1          X              X        NaN         DAP02   Die_Attach
# 2        NaN              X        NaN         DAP03   Die_Attach
# 3        NaN              X        NaN        DAP04a   Die_Attach
# 4        NaN              X        NaN        DAP04b   Die_Attach
# 5        NaN              X        NaN        DAP04b   Die_Attach
# 6          X              X        NaN        DAP04c   Die_Attach
# 7        NaN              X        NaN        DAP05a   Die_Attach
# 8        NaN              X        NaN        DAP05b   Die_Attach
# 9        NaN              X        NaN        DAP05c   Die_Attach
# 10       NaN              X        NaN        DAP05c   Die_Attach
# 11       NaN              X        NaN         DAP06   Die_Attach
# 12       NaN              X        NaN         DAP07   Die_Attach
# 13       NaN              X        NaN         DAP08   Die_Attach
# 14       NaN            NaN          X        DAP05b   Die_Attach
# 15       NaN            NaN          X         DAP08   Die_Attach
# 16         X            NaN          X         DAP09   Die_Attach
# 17       NaN            NaN          X         DAP10   Die_Attach
# 18         X            NaN          X        DAP11    Die_Attach
# 19         X            NaN          X         DAP12   Die_Attach
# 20       NaN            NaN          X         DAP13   Die_Attach
# 21         X            NaN          X         DAP14   Die_Attach
# 22       NaN            NaN          X         DAP15   Die_Attach
# 23         X            NaN          X        PDP005   Die_Attach
# 24         X            NaN          X        PDP010   Die_Attach
# 25         X            NaN          X         BSP08   Die_Attach
# 26         X            NaN          X         SEP27   Die_Attach
# 27         X            NaN          X         SEP31   Die_Attach

# %%
PBHB_mapping = pd.concat([PBHB_wirebond, PBHB_die_attach], ignore_index=True)
for col in PBHB_mapping.columns:
    if col not in ['PB_code', 'process_name']:
        PBHB_mapping[col] = PBHB_mapping[col].apply(lambda row: row.replace("X", col) if not pd.isnull(row) else row)
PBHB_mapping = PBHB_mapping[['process_name', 'PB_code', 'Au ball', 'Cu ball', 'Al wedge', 'Au wedge', 
                             'Soft solder', 'Solder paste','Diffusion solder', 'Epoxy', 
                             'DAF', 'Cu Pillar FC', 'Clip Bond',
                             'Green & yellow', 'Red & grey']]
PBHB_mapping['PBC_color'] = PBHB_mapping[['Green & yellow', 'Red & grey']].apply(lambda x: x['Green & yellow'].lower().split(" & ") if pd.isnull(x['Red & grey']) \
                                                                                 else x['Red & grey'].lower().split(" & "), axis=1)
PBHB_mapping.drop(columns=['Green & yellow', 'Red & grey'], inplace=True)
PBHB_mapping = PBHB_mapping.explode(column="PBC_color", ignore_index=True)
PBHB_mapping.columns = ['process_name', "PB_code"] + ["process_tech_name_{i}".format(i=i) for i in range(len(PBHB_mapping.columns)-3)] + ["PBC_color"]
PBHB_mapping['process_tech_name'] = PBHB_mapping[[col for col in PBHB_mapping.columns if col.startswith("process_tech_name_")]].apply(lambda x: list(i for i in x if not pd.isnull(i)), axis=1)
PBHB_mapping.drop(columns=[col for col in PBHB_mapping.columns if col.startswith("process_tech_name_")], inplace=True)
PBHB_mapping = PBHB_mapping.explode(column="process_tech_name", ignore_index=True)
PBHB_mapping = PBHB_mapping.groupby(['process_name', 'process_tech_name', 'PBC_color'], as_index=False).agg({'PB_code': list})
# PBHB_mapping['PB_codes'] = PBHB_mapping.PB_code.apply(lambda x: ", ".join(x))
PBHB_mapping
# Out:
#     process_name process_tech_name PBC_color  \
# 0     Die_Attach         Clip Bond     green
# 1     Die_Attach         Clip Bond      grey
# 2     Die_Attach         Clip Bond       red
# 3     Die_Attach         Clip Bond    yellow
# 4     Die_Attach      Cu Pillar FC     green
# 5     Die_Attach      Cu Pillar FC      grey
# 6     Die_Attach      Cu Pillar FC       red
# 7     Die_Attach      Cu Pillar FC    yellow
# 8     Die_Attach               DAF     green
# 9     Die_Attach               DAF      grey
# 10    Die_Attach               DAF       red
# 11    Die_Attach               DAF    yellow
# 12    Die_Attach  Diffusion solder     green
# 13    Die_Attach  Diffusion solder      grey
# 14    Die_Attach  Diffusion solder       red
# 15    Die_Attach  Diffusion solder    yellow
# 16    Die_Attach             Epoxy     green
# 17    Die_Attach             Epoxy      grey
# 18    Die_Attach             Epoxy       red
# 19    Die_Attach             Epoxy    yellow
# 20    Die_Attach       Soft solder     green
# 21    Die_Attach       Soft solder      grey
# 22    Die_Attach       Soft solder       red
# 23    Die_Attach       Soft solder    yellow
# 24    Die_Attach      Solder paste     green
# 25    Die_Attach      Solder paste      grey
# 26    Die_Attach      Solder paste       red
# 27    Die_Attach      Solder paste    yellow
# 28  Interconnect          Al wedge     green
# 29  Interconnect          Al wedge      grey
# 30  Interconnect          Al wedge       red
# 31  Interconnect          Al wedge    yellow
# 32  Interconnect           Au ball     green
# 33  Interconnect           Au ball      grey
# 34  Interconnect           Au ball       red
# 35  Interconnect           Au ball    yellow
# 36  Interconnect          Au wedge     green
# 37  Interconnect          Au wedge      grey
# 38  Interconnect          Au wedge       red
# 39  Interconnect          Au wedge    yellow
# 40  Interconnect           Cu ball     green
# 41  Interconnect           Cu ball      grey
# 42  Interconnect           Cu ball       red
# 43  Interconnect           Cu ball    yellow
#
#                                               PB_code
# 0                                     [DAP02, DAP04c]
# 1   [DAP09, DAP11 , DAP12, DAP14, PDP005, PDP010, ...
# 2   [DAP09, DAP11 , DAP12, DAP14, PDP005, PDP010, ...
# 3                                     [DAP02, DAP04c]
# 4   [DAP01 /PUP01, DAP02, DAP03, DAP04b, DAP04b, D...
# 5                 [DAP13, DAP15, BSP08, SEP27, SEP31]
# 6                 [DAP13, DAP15, BSP08, SEP27, SEP31]
# 7   [DAP01 /PUP01, DAP02, DAP03, DAP04b, DAP04b, D...
# 8   [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05b, D...
# 9                       [DAP05b, BSP08, SEP27, SEP31]
# 10                      [DAP05b, BSP08, SEP27, SEP31]
# 11  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05b, D...
# 12  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 13  [DAP05b, DAP08, DAP10, DAP15, BSP08, SEP27, SE...
# 14  [DAP05b, DAP08, DAP10, DAP15, BSP08, SEP27, SE...
# 15  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 16  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 17  [DAP05b, DAP14, PDP005, PDP010, BSP08, SEP27, ...
# 18  [DAP05b, DAP14, PDP005, PDP010, BSP08, SEP27, ...
# 19  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 20  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 21  [DAP05b, DAP08, DAP10, DAP15, BSP08, SEP27, SE...
# 22  [DAP05b, DAP08, DAP10, DAP15, BSP08, SEP27, SE...
# 23  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 24  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 25  [DAP05b, DAP08, DAP10, DAP14, DAP15, PDP005, P...
# 26  [DAP05b, DAP08, DAP10, DAP14, DAP15, PDP005, P...
# 27  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 28  [INP02, INP08, INP11, INP14, INP15, INP19, INP...
# 29  [DAP14, PDP005, PDP006, PDP007, PDP008, PDP009...
# 30  [DAP14, PDP005, PDP006, PDP007, PDP008, PDP009...
# 31  [INP02, INP08, INP11, INP14, INP15, INP19, INP...
# 32  [INP01, INP03, INP04, INP05, INP06, INP07, INP...
# 33  [DAP14, PDP005, PDP006, PDP007, PDP008, PDP009...
# 34  [DAP14, PDP005, PDP006, PDP007, PDP008, PDP009...
# 35  [INP01, INP03, INP04, INP05, INP06, INP07, INP...
# 36  [INP02, INP08, INP11, INP14, INP15, INP19, INP...
# 37  [DAP14, PDP005, PDP006, PDP007, PDP008, PDP009...
# 38  [DAP14, PDP005, PDP006, PDP007, PDP008, PDP009...
# 39  [INP02, INP08, INP11, INP14, INP15, INP19, INP...
# 40  [INP01, INP03, INP04, INP05, INP06, INP07, INP...
# 41  [INP24, INP25, INP26, DAP14, PDP005, PDP006, P...
# 42  [INP24, INP25, INP26, DAP14, PDP005, PDP006, P...
# 43  [INP01, INP03, INP04, INP05, INP06, INP07, INP...

# %%
process_table = pd.read_sql("select * from Process", conn)

# %%
Process_PBHB_mapping = process_table.merge(PBHB_mapping, on=['process_name', 'process_tech_name', 'PBC_color'], how='inner')[['process_id', 'PB_code']]
Process_PBHB_mapping.head(3)
# Out:
#    process_id                                            PB_code
# 0           2  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 1           3  [DAP01 /PUP01, DAP02, DAP03, DAP04a, DAP05a, D...
# 2           4  [DAP05b, DAP08, DAP10, DAP15, BSP08, SEP27, SE...

# %%
Process_PBHB_mapping['PB_codes'] = Process_PBHB_mapping['PB_code'].apply(lambda row: [[i+1, x] for i,x in enumerate(row)])
Process_PBHB_mapping.drop(columns=['PB_code'], inplace=True)
Process_PBHB_mapping = Process_PBHB_mapping.explode(column='PB_codes', ignore_index=True)
Process_PBHB_mapping[['num','PB_code']] = pd.DataFrame(Process_PBHB_mapping.PB_codes.tolist(), index=Process_PBHB_mapping.index)

# %%
Process_PBHB_mapping.drop(columns=["PB_codes"], inplace=True)

# %%
Process_PBHB_mapping.head(3)
# Out:
#    process_id  num       PB_code
# 0           2    1  DAP01 /PUP01
# 1           2    2         DAP02
# 2           2    3         DAP03

# %%
# conn.execute("DROP TABLE Process_PBHB_mapping;")
conn.execute(table_to_sql(Process_PBHB_mapping, 'Process_PBHB_mapping', 
                          int_cols=['process_id', 'num'],
                         ))

Process_PBHB_mapping.to_sql('Process_PBHB_mapping', con=conn, 
                            if_exists='append', index=False)

conn.execute("ALTER TABLE Process_PBHB_mapping ADD FOREIGN KEY (process_id) REFERENCES Process(process_id);")

# %%
# conn.execute("drop table PDR_sessions;")
# conn.execute("drop table Sessions;")

query_sql = """
CREATE TABLE `Sessions` (
  `session_id` INT NOT NULL AUTO_INCREMENT,
  `submit_time` DATETIME,
  `username` varchar(50) DEFAULT NULL,
   PRIMARY KEY (session_id)
);
"""
conn.execute(query_sql)

query_sql = """
CREATE TABLE `PDR_sessions` (
  `session_id` int,
  `process_id` int,
  `PB_num` int DEFAULT NULL,
  `PB_code` varchar(18) DEFAULT NULL,
  `Process_results_Min` float DEFAULT NULL,
  `Process_results_Max` float DEFAULT NULL,
  `Process_results_Ave` float DEFAULT NULL,
  `Process_results_sigma` float DEFAULT NULL,
  `Process_results_attribute` varchar(50) DEFAULT NULL,
  `Target_achieved` boolean DEFAULT NULL,
  `Rec_action_number` varchar(20) DEFAULT NULL,
  FOREIGN KEY (session_id) REFERENCES Sessions(session_id),
  FOREIGN KEY (process_id) REFERENCES Process(process_id)
);
"""
conn.execute(query_sql)

# %% [markdown]
# # GPPT

# %%
GPPT_templates_wirebond = pd.read_excel("../data/wire bond GPPT.xlsx", 
                                        sheet_name="Template Overview",
                                       )
GPPT_templates_wirebond.columns = ['Template', 'Machine_Model', 'Remark']
GPPT_templates_wirebond['Machine_Model'] = GPPT_templates_wirebond['Machine_Model'].str.split("\n ")
GPPT_templates_wirebond = GPPT_templates_wirebond.explode(column="Machine_Model", ignore_index=True)
GPPT_templates_wirebond
# Out:
#                 Template       Machine_Model                Remark
# 0        ASM Template #1        iHawk Xtreme           Ball Bonder
# 1        ASM Template #1   iHawk Xtreme GoCu           Ball Bonder
# 2        ASM Template #1   iHawk Xpress GoCu           Ball Bonder
# 3        ASM Template #1   Eagle Xtreme GoCu           Ball Bonder
# 4        ASM Template #1          Eagle AERO           Ball Bonder
# 5        ASM Template #1               iHawk           Ball Bonder
# 6        ASM Template #2            Eagle 60           Ball Bonder
# 7   Shinkawa Template #1            ACB-1000           Ball Bonder
# 8   Shinkawa Template #1            ACB-3000           Ball Bonder
# 9   Shinkawa Template #1            UTC-1000           Ball Bonder
# 10  Shinkawa Template #1            UTC-2000           Ball Bonder
# 11  Shinkawa Template #1            UTC-3000           Ball Bonder
# 12  Shinkawa Template #1      UTC-5000 NeoCu           Ball Bonder
# 13  Shinkawa Template #1            UTC-5100           Ball Bonder
# 14  Shinkawa Template #2              ACB-35           Ball Bonder
# 15  Shinkawa Template #2             ACB-400           Ball Bonder
# 16      ESEC Template #1           ESEC 3100           Ball Bonder
# 17      ESEC Template #1           ESEC 3200           Ball Bonder
# 18      ESEC Template #2           ESEC 3088           Ball Bonder
# 19       K&S Template #1               IConn           Ball Bonder
# 20       K&S Template #2              OE7200          Wedge Bonder
# 21       K&S Template #2          OE7200Plus          Wedge Bonder
# 22       K&S Template #2        Power Fusion          Wedge Bonder
# 23       K&S Template #2              OE3600          Wedge Bonder
# 24       K&S Template #2          OE3600Plus          Wedge Bonder
# 25       K&S Template #2            Asterion          Wedge Bonder
# 26       K&S Template #3              OE360C  Wedge Bonder for HPS
# 27       F&K Template #1       Delvotec G5-2          Wedge Bonder
# 28       F&K Template #1     Delvotec G5-2HS          Wedge Bonder
# 29       F&K Template #2       Delvotec G4-2          Wedge Bonder
# 30       F&K Template #2     Delvotec G4-2HS          Wedge Bonder
# 31     Hesse Template #1           H&K BJ820          Wedge Bonder
# 32     Hesse Template #2           H&K BJ820  Wedge Bonder for HPS
# 33     Hesse Template #2           H&K BJ920  Wedge Bonder for HPS
# 34     Hesse Template #2           H&K BJ939  Wedge Bonder for HPS
# 35     Cho-Onpa Template             Rebo-07          Wedge Bonder
# 36     Cho-Onpa Template             Rebo-09          Wedge Bonder

# %%
GPPT_templates_dieattach = pd.read_excel("../data/Die attach GPPT.xlsx", 
                                         sheet_name="FrontPage",
                                         skiprows=list(range(4))+list(range(20,25)),
                                         usecols=[1,2]
                                       )
GPPT_templates_dieattach['Remark'] = None
GPPT_templates_dieattach.columns = ['Machine_Model', 'Template', 'Remark']
GPPT_templates_dieattach['Machine_Model'] = GPPT_templates_dieattach['Machine_Model'].str.split(", ")
GPPT_templates_dieattach = GPPT_templates_dieattach.explode(column="Machine_Model", ignore_index=True)
GPPT_templates_dieattach
# Out:
#                      Machine_Model               Template Remark
# 0                           AD8312          ASM-AD8312/FC   None
# 1                         AD8312FC          ASM-AD8312/FC   None
# 2                            AD838              ASM-AD838   None
# 3                       Texus 4000   TEXUS-4600/4200/4000   None
# 4                       Texus 4200   TEXUS-4600/4200/4000   None
# 5                       Texus 4600   TEXUS-4600/4200/4000   None
# 6                         ESEC2100          BESI-ESEC2100   None
# 7                 BESI Datacon Evo       BESI-Datacon Evo   None
# 8                        ESEC 2007     BESI-ESEC2007/2009   None
# 9                        ESEC 2009     BESI-ESEC2007/2009   None
# 10                       ESEC 2008         BESI-ESEC 2008   None
# 11                          SD890A      ASM SD890A_SD832D   None
# 12                          SD832D      ASM SD890A_SD832D   None
# 13                          SD8312             ASM SD8312   None
# 14               Texus 3xxx series             TEXUS-3xxx   None
# 15               Alphasem Easyline          Alphasem 8xxx   None
# 16             Muhlbauer FCM 10000               FCM10000   None
# 17             BESI Datacon 8800FC         Datacon 8800FC   None
# 18  ASM Clip Bonder + RO830 Reflow  ASM ClipBond + Reflow   None
# 19                         AD8312+         ASM AD8312Plus   None

# %%
GPPT_machine_templates_table = pd.concat([GPPT_templates_wirebond, GPPT_templates_dieattach], ignore_index=True)
GPPT_machine_templates_table
# Out:
#                  Template                   Machine_Model  \
# 0         ASM Template #1                    iHawk Xtreme
# 1         ASM Template #1               iHawk Xtreme GoCu
# 2         ASM Template #1               iHawk Xpress GoCu
# 3         ASM Template #1               Eagle Xtreme GoCu
# 4         ASM Template #1                      Eagle AERO
# 5         ASM Template #1                           iHawk
# 6         ASM Template #2                        Eagle 60
# 7    Shinkawa Template #1                        ACB-1000
# 8    Shinkawa Template #1                        ACB-3000
# 9    Shinkawa Template #1                        UTC-1000
# 10   Shinkawa Template #1                        UTC-2000
# 11   Shinkawa Template #1                        UTC-3000
# 12   Shinkawa Template #1                  UTC-5000 NeoCu
# 13   Shinkawa Template #1                        UTC-5100
# 14   Shinkawa Template #2                          ACB-35
# 15   Shinkawa Template #2                         ACB-400
# 16       ESEC Template #1                       ESEC 3100
# 17       ESEC Template #1                       ESEC 3200
# 18       ESEC Template #2                       ESEC 3088
# 19        K&S Template #1                           IConn
# 20        K&S Template #2                          OE7200
# 21        K&S Template #2                      OE7200Plus
# 22        K&S Template #2                    Power Fusion
# 23        K&S Template #2                          OE3600
# 24        K&S Template #2                      OE3600Plus
# 25        K&S Template #2                        Asterion
# 26        K&S Template #3                          OE360C
# 27        F&K Template #1                   Delvotec G5-2
# 28        F&K Template #1                 Delvotec G5-2HS
# 29        F&K Template #2                   Delvotec G4-2
# 30        F&K Template #2                 Delvotec G4-2HS
# 31      Hesse Template #1                       H&K BJ820
# 32      Hesse Template #2                       H&K BJ820
# 33      Hesse Template #2                       H&K BJ920
# 34      Hesse Template #2                       H&K BJ939
# 35      Cho-Onpa Template                         Rebo-07
# 36      Cho-Onpa Template                         Rebo-09
# 37          ASM-AD8312/FC                          AD8312
# 38          ASM-AD8312/FC                        AD8312FC
# 39              ASM-AD838                           AD838
# 40   TEXUS-4600/4200/4000                      Texus 4000
# 41   TEXUS-4600/4200/4000                      Texus 4200
# 42   TEXUS-4600/4200/4000                      Texus 4600
# 43          BESI-ESEC2100                        ESEC2100
# 44       BESI-Datacon Evo                BESI Datacon Evo
# 45     BESI-ESEC2007/2009                       ESEC 2007
# 46     BESI-ESEC2007/2009                       ESEC 2009
# 47         BESI-ESEC 2008                       ESEC 2008
# 48      ASM SD890A_SD832D                          SD890A
# 49      ASM SD890A_SD832D                          SD832D
# 50             ASM SD8312                          SD8312
# 51             TEXUS-3xxx               Texus 3xxx series
# 52          Alphasem 8xxx               Alphasem Easyline
# 53               FCM10000             Muhlbauer FCM 10000
# 54         Datacon 8800FC             BESI Datacon 8800FC
# 55  ASM ClipBond + Reflow  ASM Clip Bonder + RO830 Reflow
# 56         ASM AD8312Plus                         AD8312+
#
#                   Remark
# 0            Ball Bonder
# 1            Ball Bonder
# 2            Ball Bonder
# 3            Ball Bonder
# 4            Ball Bonder
# 5            Ball Bonder
# 6            Ball Bonder
# 7            Ball Bonder
# 8            Ball Bonder
# 9            Ball Bonder
# 10           Ball Bonder
# 11           Ball Bonder
# 12           Ball Bonder
# 13           Ball Bonder
# 14           Ball Bonder
# 15           Ball Bonder
# 16           Ball Bonder
# 17           Ball Bonder
# 18           Ball Bonder
# 19           Ball Bonder
# 20          Wedge Bonder
# 21          Wedge Bonder
# 22          Wedge Bonder
# 23          Wedge Bonder
# 24          Wedge Bonder
# 25          Wedge Bonder
# 26  Wedge Bonder for HPS
# 27          Wedge Bonder
# 28          Wedge Bonder
# 29          Wedge Bonder
# 30          Wedge Bonder
# 31          Wedge Bonder
# 32  Wedge Bonder for HPS
# 33  Wedge Bonder for HPS
# 34  Wedge Bonder for HPS
# 35          Wedge Bonder
# 36          Wedge Bonder
# 37                  None
# 38                  None
# 39                  None
# 40                  None
# 41                  None
# 42                  None
# 43                  None
# 44                  None
# 45                  None
# 46                  None
# 47                  None
# 48                  None
# 49                  None
# 50                  None
# 51                  None
# 52                  None
# 53                  None
# 54                  None
# 55                  None
# 56                  None

# %%
# conn.execute("DROP TABLE GPPT_machine_template;")
conn.execute(table_to_sql(GPPT_machine_templates_table, 'GPPT_machine_template'))

GPPT_machine_templates_table.to_sql('GPPT_machine_template', con=conn, 
                            if_exists='append', index=False)

# %%
wirebond_GPPT_templates = list(GPPT_templates_wirebond.Template.unique())
GPPT_wirebond_template = []
for sheet in wirebond_GPPT_templates:
    try:
        df_temp = pd.read_excel("../data/wire bond GPPT.xlsx", 
                            sheet_name=sheet,
                            usecols=[2,3,4],
                            skiprows=range(pd.read_excel("../data/wire bond GPPT.xlsx", 
                                              sheet_name=sheet,
                                              usecols=[1]
                                             )['Unnamed: 1'].tolist().index('Main Parameter')+2),
                           )

        df_temp.dropna(subset=['Parameter Name'], inplace=True)
        df_temp.columns = ['Work Step', 'Num', 'Parameter Name']
        df_temp.fillna(method='ffill', inplace=True)
        df_temp['Template'] = sheet
        GPPT_wirebond_template.append(df_temp)
    except ValueError: print(sheet)
GPPT_wirebond_template = pd.concat(GPPT_wirebond_template, ignore_index=True)[["Template", 'Work Step', 'Num', 'Parameter Name']]
GPPT_wirebond_template.head(20)
# Out:
# K&S Template #3
# Hesse Template #2
#            Template                           Work Step  Num  \
# 0   ASM Template #1                             Heating  1.1
# 1   ASM Template #1                             Heating  1.2
# 2   ASM Template #1                             Heating  1.3
# 3   ASM Template #1  Indexer Gas Flow \n(if applicable)  2.1
# 4   ASM Template #1  Indexer Gas Flow \n(if applicable)  2.2
# 5   ASM Template #1  Indexer Gas Flow \n(if applicable)  2.3
# 6   ASM Template #1  Indexer Gas Flow \n(if applicable)  2.4
# 7   ASM Template #1  Indexer Gas Flow \n(if applicable)  2.5
# 8   ASM Template #1  Indexer Gas Flow \n(if applicable)  2.6
# 9   ASM Template #1   Cu Kit Gas Flow \n(if applicable)  3.1
# 10  ASM Template #1   Cu Kit Gas Flow \n(if applicable)  3.2
# 11  ASM Template #1   Cu Kit Gas Flow \n(if applicable)  3.3
# 12  ASM Template #1                                 EFO  4.1
# 13  ASM Template #1                                 EFO  4.2
# 14  ASM Template #1                                 EFO  4.3
# 15  ASM Template #1                            1st Bond  5.1
# 16  ASM Template #1                            1st Bond  5.2
# 17  ASM Template #1                            1st Bond  5.3
# 18  ASM Template #1                            1st Bond  5.4
# 19  ASM Template #1                            1st Bond  5.5
#
#              Parameter Name
# 0                Pre Heater
# 1               Main Heater
# 2               Post Heater
# 3                    Buffer
# 4                  PH & Cvr
# 5                  H/Tunnel
# 6                    Heater
# 7                   W/Clamp
# 8                  PB & Cvr
# 9                   E Torch
# 10                   Cu Kit
# 11               3rd Nozzle
# 12              EFO Current
# 13                 EFO Time
# 14              Tail Length
# 15          BQM Power Level
# 16        BQM Power Control
# 17  Reference Search Height
# 18             Search Speed
# 19                   RCD N1

# %%
dieattach_GPPT_templates = [sheet for sheet in pd.ExcelFile('../data/Die attach GPPT.xlsx').sheet_names if sheet != 'FrontPage']
GPPT_dieattach_template = []
for sheet in dieattach_GPPT_templates:
    df_temp = pd.read_excel("../data/Die attach GPPT.xlsx", 
                                sheet_name=sheet,
                                usecols=[2,3,4],
                                skiprows=range(pd.read_excel("../data/Die attach GPPT.xlsx", 
                                              sheet_name=sheet,
                                              usecols=[1],
                                             )['Unnamed: 1'].tolist().index('Main Parameter')+2),
                               )
    try:
        df_temp.dropna(subset=['Parameter Name'], inplace=True)
        df_temp.columns = ['Work Step', 'Num', 'Parameter Name']
        df_temp.fillna(method='ffill', inplace=True)
        df_temp['Template'] = sheet.split(maxsplit=1)[-1].strip()
        GPPT_dieattach_template.append(df_temp)
    except ValueError: print(sheet)
GPPT_dieattach_template = pd.concat(GPPT_dieattach_template, ignore_index=True)[["Template", 'Work Step', 'Num', 'Parameter Name']]
GPPT_dieattach_template.head(20)
# Out:
#          Template                 Work Step  Num  \
# 0   ASM-AD8312_FC  Pick Up Head ( Flipper )  3.1
# 1   ASM-AD8312_FC  Pick Up Head ( Flipper )  3.2
# 2   ASM-AD8312_FC  Pick Up Head ( Flipper )  3.3
# 3   ASM-AD8312_FC  Pick Up Head ( Flipper )  3.4
# 4   ASM-AD8312_FC  Pick Up Head ( Flipper )  3.5
# 5   ASM-AD8312_FC  Pick Up Head ( Flipper )  3.6
# 6   ASM-AD8312_FC  Pick Up Head ( Flipper )  3.7
# 7   ASM-AD8312_FC  Pick Up Head ( Flipper )  4.1
# 8   ASM-AD8312_FC  Pick Up Head ( Flipper )  4.2
# 9   ASM-AD8312_FC                 Bond Head  4.3
# 10  ASM-AD8312_FC                 Bond Head  4.4
# 11  ASM-AD8312_FC                 Bond Head  4.5
# 12  ASM-AD8312_FC  Time Pressure Dispensing  5.1
# 13  ASM-AD8312_FC  Time Pressure Dispensing  5.2
# 14  ASM-AD8312_FC  Time Pressure Dispensing  5.3
# 15  ASM-AD8312_FC  Time Pressure Dispensing  5.4
# 16  ASM-AD8312_FC  Time Pressure Dispensing  5.5
# 17  ASM-AD8312_FC  Time Pressure Dispensing  5.6
# 18  ASM-AD8312_FC                   Bonding  6.1
# 19  ASM-AD8312_FC                   Bonding  6.2
#
#                         Parameter Name
# 0                      Pick delay (ms)
# 1                    Expansion Setting
# 2                Ejector up level (um)
# 3                Ejector up delay (ms)
# 4                 Sync Pick speed (ms)
# 5               Pick search heigh (um)
# 6               Pick search delay (ms)
# 7                      Pick delay (ms)
# 8                           Pick force
# 9                 Sync Pick speed (ms)
# 10             Pick search height (um)
# 11              Pick search delay (ms)
# 12                  EWZ Contact Offset
# 13                            Pressure
# 14  Velocity,Acc/Dec,Jerk,Search Speed
# 15                         Pre Squeeze
# 16                        Post Squeeze
# 17              Writing pattern & size
# 18                          Bond Delay
# 19                          Bond Force

# %%
len(GPPT_wirebond_template),len(GPPT_dieattach_template)
# Out:
# (692, 367)

# %%
GPPT_template_parameters_table = pd.concat([GPPT_wirebond_template, GPPT_dieattach_template], ignore_index=True)
GPPT_template_parameters_table
# Out:
#              Template                           Work Step  Num  \
# 0     ASM Template #1                             Heating  1.1
# 1     ASM Template #1                             Heating  1.2
# 2     ASM Template #1                             Heating  1.3
# 3     ASM Template #1  Indexer Gas Flow \n(if applicable)  2.1
# 4     ASM Template #1  Indexer Gas Flow \n(if applicable)  2.2
# ...               ...                                 ...  ...
# 1054      ASM-AD8312+                             Bonding  5.1
# 1055      ASM-AD8312+                             Bonding  5.2
# 1056      ASM-AD8312+                             Bonding  5.3
# 1057      ASM-AD8312+                             Bonding  5.4
# 1058      ASM-AD8312+                             Bonding  5.5
#
#          Parameter Name
# 0            Pre Heater
# 1           Main Heater
# 2           Post Heater
# 3                Buffer
# 4              PH & Cvr
# ...                 ...
# 1054         Bond Delay
# 1055         Bond Force
# 1056  Bond level Offset
# 1057  Bond Search Level
# 1058   BHZ Search Speed
#
# [1059 rows x 4 columns]

# %%
# conn.execute("DROP TABLE GPPT_template_parameters;")
conn.execute(table_to_sql(GPPT_template_parameters_table, 'GPPT_template_parameters', float_cols=["Num"]))

GPPT_template_parameters_table.to_sql('GPPT_template_parameters', con=conn, 
                            if_exists='append', index=False)

# %% [markdown]
# #### resources
# - https://stackoverflow.com/questions/68852940/how-to-create-two-dependent-dynamic-dropdown-lists-using-flask
# - https://www.geeksforgeeks.org/connect-flask-to-a-database-with-flask-sqlalchemy/?ref=rp
# - https://stackoverflow.com/questions/63434179/how-to-read-a-custom-html-table-information-from-client-side-into-flask-backend
